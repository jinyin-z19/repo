# %%
import numpy as np              ##创建数组
c=np.array([[1,2,3],[4,5,6]])
d=np.array([2,6,8])
#c
#c*d
#d=np.sqrt(c)
#d=np.zeros((3,3))
np.dot(c,d)
d*=2
c.transpose()
d.reshape(3,1)
e=np.random.random(6)
e.reshape(2,3)

def sh(x):
    return(1/(1+np.exp(-x)))
print(sh(1))

def tanh(x):
    return((np.exp(x)-np.exp(-x))/(np.exp(x)+np.exp(-x)))
print(tanh(1))

def RELU(x):
    if x>0 :
        return x
    else:
        return 0
print(RELU(-1))

def nuRelu(a,b):        ##relu单元
    return RELU(np.dot(a,b))
m=([1,0,1])
n=([-0.21,0.3,0.7])

print(nuRelu(m,n))

def nulog(a,b):        ##relu单元
    return sh(np.dot(a,b))

print(nulog(m,n))

def nuAND(a):   ### 与函数神经元
    if sh(np.dot(a,([20,20]))-30)>0.5:
        return True
    else:
        return False
print(nuAND(([0,0])))

def nuOR(a):   ### 或函数神经元
    if sh(np.dot(a,([20,20]))-10)>0.5:
        return True
    else:
        return False
print(nuOR(([1,1])))

def nuOR(a):   ### 或函数神经元
    if sh(np.dot(a,([20,20]))-10)>0.5:
        return True
    else:
        return False
print(nuOR(([1,1])))

def nuNOT(a):   ### 或函数神经元
    if a<0.5:
        return True
    else:
        return False
print(nuNOT(1))

def nuNAND(a):
     if sh(np.dot(a,([-20,-20]))+30)>0.5:
        return True
     else:
        return False
print(nuNAND(([0,0])))

def softmax(a):
    b=a
    return np.exp(b)/np.exp(a).sum()
b=softmax(([1,2,3,4,5,6,7,8,9]))
print(b)
def logit(x):
    return(np.log(x/(1-x)))
print(logit(0.5))
# Out:
# 0.7310585786300049
# 0.7615941559557649
# 0
# 0.49
# 0.6201064323430902
# False
# True
# True
# False
# True
# [2.12078996e-04 5.76490482e-04 1.56706360e-03 4.25972051e-03
#  1.15791209e-02 3.14753138e-02 8.55587737e-02 2.32572860e-01
#  6.32198578e-01]
# 0.0
